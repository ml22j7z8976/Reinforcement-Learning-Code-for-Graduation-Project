# %%
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import time
from matplotlib import pyplot as plt
from gym.wrappers import GrayScaleObservation
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import VecFrameStack
import os
from stable_baselines3 import PPO

from stable_baselines3.common.results_plotter import load_results, ts2xy
import numpy as np
from stable_baselines3.common.callbacks import BaseCallback

#import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

monitor_dir = r'./monitor_log/'
os.makedirs(monitor_dir,exist_ok=True)
env = Monitor(env,monitor_dir)

env = GrayScaleObservation(env,keep_dim=True)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env,4,channels_order='last')

# %%
tensorboard_log = r'./tensorboard_log/'
learning_rate = 1e-6
n_steps = 128
model = PPO("CnnPolicy", env, verbose=1,
            tensorboard_log = tensorboard_log,
            learning_rate = learning_rate,
            n_steps = n_steps)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq, save_model_dir, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = os.path.join(save_model_dir, 'best_model/')
        self.best_mean_reward = -np.inf

    # def _init_callback(self) -> None:
    def _init_callback(self):
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    # def _on_step(self) -> bool:
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            print('self.n_calls: ',self.n_calls)
            model_path1 = os.path.join(self.save_path, 'model_{}'.format(self.n_calls))
            self.model.save(model_path1)

        return True

# %%
save_model_dir = r'C:\\Users\\周靖雅\\Desktop\\RL\\代码\\RL_Mario1'
callback1 = SaveOnBestTrainingRewardCallback(1000, save_model_dir)
model.learn(total_timesteps=5000,callback=callback1)
# Out:
# Logging to ./tensorboard_log/PPO_9
# ----------------------------
# | time/              |     |
# |    fps             | 11  |
# |    iterations      | 1   |
# |    time_elapsed    | 10  |
# |    total_timesteps | 128 |
# ----------------------------
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 16            |
# |    iterations           | 2             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 1.5636906e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00239       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 182           |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000224     |
# |    value_loss           | 381           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 18            |
# |    iterations           | 3             |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 384           |
# | train/                  |               |
# |    approx_kl            | 1.8230639e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00314       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 242           |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -8.11e-05     |
# |    value_loss           | 531           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 20           |
# |    iterations           | 4            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 8.442439e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00218     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 462          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | 5.03e-05     |
# |    value_loss           | 951          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 21           |
# |    iterations           | 5            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 640          |
# | train/                  |              |
# |    approx_kl            | 4.596077e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.016       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.2          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000251    |
# |    value_loss           | 3.57         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 22            |
# |    iterations           | 6             |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 768           |
# | train/                  |               |
# |    approx_kl            | 7.3597766e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0145       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.01          |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000321     |
# |    value_loss           | 2.19          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 23            |
# |    iterations           | 7             |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 896           |
# | train/                  |               |
# |    approx_kl            | 3.1092204e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0172        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 159           |
# |    n_updates            | 60            |
# |    policy_gradient_loss | 8.86e-05      |
# |    value_loss           | 371           |
# -------------------------------------------
# self.n_calls:  1000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 22           |
# |    iterations           | 8            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 6.845221e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00934      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.02         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -9.17e-05    |
# |    value_loss           | 3.55         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 23            |
# |    iterations           | 9             |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 1152          |
# | train/                  |               |
# |    approx_kl            | 5.7681464e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0125       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.253         |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000228     |
# |    value_loss           | 1.14          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 23            |
# |    iterations           | 10            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 1280          |
# | train/                  |               |
# |    approx_kl            | 3.7872232e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0172        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0853        |
# |    n_updates            | 90            |
# |    policy_gradient_loss | 4.73e-05      |
# |    value_loss           | 1.21          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 24            |
# |    iterations           | 11            |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 1408          |
# | train/                  |               |
# |    approx_kl            | 3.6521815e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0403       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.294         |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000287     |
# |    value_loss           | 0.732         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 24            |
# |    iterations           | 12            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 1.2055971e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.079         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0761        |
# |    n_updates            | 110           |
# |    policy_gradient_loss | 5.44e-05      |
# |    value_loss           | 0.73          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 25            |
# |    iterations           | 13            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 1664          |
# | train/                  |               |
# |    approx_kl            | 3.8873404e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0304       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.142         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000228     |
# |    value_loss           | 0.344         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 14           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 1792         |
# | train/                  |              |
# |    approx_kl            | 7.310882e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0102       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.207        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -1.22e-05    |
# |    value_loss           | 0.575        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 25            |
# |    iterations           | 15            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 1920          |
# | train/                  |               |
# |    approx_kl            | 5.2526593e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00985      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 66.2          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | 2.05e-05      |
# |    value_loss           | 129           |
# -------------------------------------------
# self.n_calls:  2000
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | 993          |
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 16           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 6.891787e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00168     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 317          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | 1.11e-05     |
# |    value_loss           | 661          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | 993          |
# | time/                   |              |
# |    fps                  | 25           |
# |    iterations           | 17           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 2176         |
# | train/                  |              |
# |    approx_kl            | 7.278286e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.000389    |
# |    learning_rate        | 1e-06        |
# |    loss                 | 96.7         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -1.15e-05    |
# |    value_loss           | 225          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 25            |
# |    iterations           | 18            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 2304          |
# | train/                  |               |
# |    approx_kl            | 6.4168125e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00367      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 189           |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -6.76e-05     |
# |    value_loss           | 387           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92e+03    |
# |    ep_rew_mean          | 993         |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 19          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 2432        |
# | train/                  |             |
# |    approx_kl            | 5.76023e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.0125      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 259         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -6.74e-05   |
# |    value_loss           | 546         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 26            |
# |    iterations           | 20            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 6.3795596e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0144       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 262           |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -9.63e-05     |
# |    value_loss           | 582           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | 993          |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 21           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 2688         |
# | train/                  |              |
# |    approx_kl            | 8.023344e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0122       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 52.4         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -3.13e-05    |
# |    value_loss           | 105          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 27            |
# |    iterations           | 22            |
# |    time_elapsed         | 104           |
# |    total_timesteps      | 2816          |
# | train/                  |               |
# |    approx_kl            | 3.6973506e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0611       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 3.05          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -8.93e-05     |
# |    value_loss           | 7.69          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | 993          |
# | time/                   |              |
# |    fps                  | 27           |
# |    iterations           | 23           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 2944         |
# | train/                  |              |
# |    approx_kl            | 6.221235e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0691       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.514        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -4.43e-05    |
# |    value_loss           | 3.53         |
# ------------------------------------------
# self.n_calls:  3000
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 27            |
# |    iterations           | 24            |
# |    time_elapsed         | 113           |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 5.7695433e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0516       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.338         |
# |    n_updates            | 230           |
# |    policy_gradient_loss | 3.03e-05      |
# |    value_loss           | 2.47          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 27            |
# |    iterations           | 25            |
# |    time_elapsed         | 117           |
# |    total_timesteps      | 3200          |
# | train/                  |               |
# |    approx_kl            | 7.0175156e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0547        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.34          |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -1.89e-05     |
# |    value_loss           | 1.73          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 27            |
# |    iterations           | 26            |
# |    time_elapsed         | 121           |
# |    total_timesteps      | 3328          |
# | train/                  |               |
# |    approx_kl            | 1.4482066e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00354       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.125         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | 0.00016       |
# |    value_loss           | 1.24          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 27            |
# |    iterations           | 27            |
# |    time_elapsed         | 125           |
# |    total_timesteps      | 3456          |
# | train/                  |               |
# |    approx_kl            | 1.1064112e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.103        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.102         |
# |    n_updates            | 260           |
# |    policy_gradient_loss | 5.28e-05      |
# |    value_loss           | 1.01          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 27            |
# |    iterations           | 28            |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 1.0784715e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0586        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.188         |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -7.61e-05     |
# |    value_loss           | 0.596         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 27            |
# |    iterations           | 29            |
# |    time_elapsed         | 132           |
# |    total_timesteps      | 3712          |
# | train/                  |               |
# |    approx_kl            | 4.4191256e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.14          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.104         |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -2.22e-05     |
# |    value_loss           | 0.549         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | 993          |
# | time/                   |              |
# |    fps                  | 28           |
# |    iterations           | 30           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 7.255003e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.011       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.105        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -4e-05       |
# |    value_loss           | 0.377        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 28            |
# |    iterations           | 31            |
# |    time_elapsed         | 140           |
# |    total_timesteps      | 3968          |
# | train/                  |               |
# |    approx_kl            | 2.3655593e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0203       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.154         |
# |    n_updates            | 300           |
# |    policy_gradient_loss | 5.69e-06      |
# |    value_loss           | 0.599         |
# -------------------------------------------
# self.n_calls:  4000
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 28            |
# |    iterations           | 32            |
# |    time_elapsed         | 145           |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 2.2281893e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0321        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.114         |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000113     |
# |    value_loss           | 0.357         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 28            |
# |    iterations           | 33            |
# |    time_elapsed         | 149           |
# |    total_timesteps      | 4224          |
# | train/                  |               |
# |    approx_kl            | 1.2284145e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0285        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.191         |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -2.69e-05     |
# |    value_loss           | 0.673         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | 993          |
# | time/                   |              |
# |    fps                  | 28           |
# |    iterations           | 34           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 4352         |
# | train/                  |              |
# |    approx_kl            | 2.508983e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00252      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.194        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -7.29e-05    |
# |    value_loss           | 0.358        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 28            |
# |    iterations           | 35            |
# |    time_elapsed         | 157           |
# |    total_timesteps      | 4480          |
# | train/                  |               |
# |    approx_kl            | 1.2707897e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00354      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0719        |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -7.99e-05     |
# |    value_loss           | 0.192         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 28            |
# |    iterations           | 36            |
# |    time_elapsed         | 161           |
# |    total_timesteps      | 4608          |
# | train/                  |               |
# |    approx_kl            | 1.1092052e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.009         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0707        |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -5.63e-05     |
# |    value_loss           | 0.156         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 28            |
# |    iterations           | 37            |
# |    time_elapsed         | 165           |
# |    total_timesteps      | 4736          |
# | train/                  |               |
# |    approx_kl            | 5.5343844e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00774       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.238         |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000348     |
# |    value_loss           | 0.469         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 28            |
# |    iterations           | 38            |
# |    time_elapsed         | 169           |
# |    total_timesteps      | 4864          |
# | train/                  |               |
# |    approx_kl            | 3.6470592e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.01         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.163         |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000111     |
# |    value_loss           | 0.305         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | 993          |
# | time/                   |              |
# |    fps                  | 28           |
# |    iterations           | 39           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 4992         |
# | train/                  |              |
# |    approx_kl            | 1.909677e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0148       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0518       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -7.99e-05    |
# |    value_loss           | 0.135        |
# ------------------------------------------
# self.n_calls:  5000
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 993           |
# | time/                   |               |
# |    fps                  | 28            |
# |    iterations           | 40            |
# |    time_elapsed         | 178           |
# |    total_timesteps      | 5120          |
# | train/                  |               |
# |    approx_kl            | 3.7713908e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.000308     |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0943        |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000185     |
# |    value_loss           | 0.165         |
# -------------------------------------------
