# %%
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import time
from matplotlib import pyplot as plt
from stable_baselines3 import PPO
#from gym wrappers import GrayScaleObservation

env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)


#del model # remove to demonstrate saving and loading
model = PPO.load("mario_model")

obs = env.reset()
obs=obs.copy()

done = True
while True:
    if done:
        state = env.reset()
        done=False
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    obs=obs.copy()
    env.render()
# Out:
# 结束
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] 无法在设置线程模式后对其加以更改。
#   warnings.warn(str(err))
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束
# 结束

# %%
#import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

# Parallel environments
#vec_env = make_vec_env("CartPole-v1", n_envs=4)

#model = PPO("MlpPolicy", vec_env, verbose=1)
#model.learn(total_timesteps=25000)
#model.save("mario_model")

#del model # remove to demonstrate saving and loading

model = PPO.load("mario_model")

obs = env.reset()
obs=obs.copy()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    obs=obs.copy()
    env.render()
# Out:
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\temp\ipykernel_15636\180002253.py in <module>
#      19 while True:
#      20     action, _states = model.predict(obs)
# ---> 21     obs, rewards, dones, info = env.step(action)
#      22     obs=obs.copy()
#      23     env.render()
#
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\nes_py\wrappers\joypad_space.py in step(self, action)
#      72         """
#      73         # take the step and record the output
# ---> 74         return self.env.step(self._action_map[action])
#      75
#      76     def reset(self):
#
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\gym\wrappers\time_limit.py in step(self, action)
#      16             self._elapsed_steps is not None
#      17         ), "Cannot call env.step() before calling reset()"
# ---> 18         observation, reward, done, info = self.env.step(action)
#      19         self._elapsed_steps += 1
#      20         if self._elapsed_steps >= self._max_episode_steps:
#
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\nes_py\nes_env.py in step(self, action)
#     294         # if the environment is done, raise an error
#     295         if self.done:
# --> 296             raise ValueError('cannot step in a done environment! call `reset`')
#     297         # set the action on the controller
#     298         self.controllers[0][:] = action
#
# ValueError: cannot step in a done environment! call `reset`
