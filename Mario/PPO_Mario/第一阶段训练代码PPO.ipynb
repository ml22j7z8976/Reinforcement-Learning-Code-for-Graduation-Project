# %%
from nes_py.wrappers import JoypadSpace
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
import time
from matplotlib import pyplot as plt
from gym.wrappers import GrayScaleObservation
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import VecFrameStack
import os
from stable_baselines3 import PPO

from stable_baselines3.common.results_plotter import load_results, ts2xy
import numpy as np
from stable_baselines3.common.callbacks import BaseCallback

# %%
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

monitor_dir = r'./monitor_log/'
os.makedirs(monitor_dir,exist_ok=True)
env = Monitor(env,monitor_dir)

env = GrayScaleObservation(env,keep_dim=True)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env,4,channels_order='last')

# %%
tensorboard_log = r'./tensorboard_log/'
learning_rate = 1e-6
model = PPO("CnnPolicy", env, verbose=1,
            tensorboard_log = tensorboard_log,
            learning_rate = learning_rate,
            )
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq, save_model_dir, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = os.path.join(save_model_dir, 'best_model/')
        self.best_mean_reward = -np.inf

    # def _init_callback(self) -> None:
    def _init_callback(self):
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    # def _on_step(self) -> bool:
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            print('self.n_calls: ',self.n_calls)
            model_path1 = os.path.join(self.save_path, 'model_{}'.format(self.n_calls))
            self.model.save(model_path1)

        return True

# %%
# ! 设置你要保存模型的位置

save_model_dir = r'C:\\Users\\周靖雅\\Desktop\\RL\\代码\\RL_Mario3'
callback1 = SaveOnBestTrainingRewardCallback(10000, save_model_dir)

model.learn(total_timesteps=3000000,callback=callback1)
# model.save("mario_model")
# Out:
# Logging to ./tensorboard_log/PPO_10
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# -----------------------------
# | time/              |      |
# |    fps             | 53   |
# |    iterations      | 1    |
# |    time_elapsed    | 37   |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 39            |
# |    iterations           | 2             |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00010936204 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0052        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 65.1          |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000582     |
# |    value_loss           | 130           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 3           |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.000247339 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.128       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.000653   |
# |    value_loss           | 0.36        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 4            |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0004362936 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.000364    |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.127        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 0.302        |
# ------------------------------------------
# self.n_calls:  10000
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 31            |
# |    iterations           | 5             |
# |    time_elapsed         | 321           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 8.3036866e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0518        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 17.4          |
# |    n_updates            | 40            |
# |    policy_gradient_loss | 7.92e-05      |
# |    value_loss           | 35.5          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 31            |
# |    iterations           | 6             |
# |    time_elapsed         | 392           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00011461761 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.161         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 20.8          |
# |    n_updates            | 50            |
# |    policy_gradient_loss | 5.63e-05      |
# |    value_loss           | 52.4          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 31            |
# |    iterations           | 7             |
# |    time_elapsed         | 460           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00049452874 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.227         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0995        |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000954     |
# |    value_loss           | 0.398         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 8            |
# |    time_elapsed         | 529          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0006865399 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.808        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0427       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 0.283        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 30            |
# |    iterations           | 9             |
# |    time_elapsed         | 599           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00090496347 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.355         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 27.1          |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000103     |
# |    value_loss           | 93            |
# -------------------------------------------
# self.n_calls:  20000
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 10           |
# |    time_elapsed         | 672          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0003786358 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.207        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000438    |
# |    value_loss           | 0.617        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 11           |
# |    time_elapsed         | 738          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0003496642 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.92        |
# |    explained_variance   | 0.725        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.112        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000474    |
# |    value_loss           | 0.43         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.41e+04      |
# |    ep_rew_mean          | 529           |
# | time/                   |               |
# |    fps                  | 30            |
# |    iterations           | 12            |
# |    time_elapsed         | 806           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 2.9626099e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | -0.104        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 8.61          |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000221     |
# |    value_loss           | 19.8          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.41e+04     |
# |    ep_rew_mean          | 529          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 13           |
# |    time_elapsed         | 873          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0009396648 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 101          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.000176     |
# |    value_loss           | 194          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.41e+04      |
# |    ep_rew_mean          | 529           |
# | time/                   |               |
# |    fps                  | 30            |
# |    iterations           | 14            |
# |    time_elapsed         | 942           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00018758181 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.588         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.079         |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000145     |
# |    value_loss           | 0.492         |
# -------------------------------------------
# self.n_calls:  30000
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.41e+04     |
# |    ep_rew_mean          | 529          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 15           |
# |    time_elapsed         | 1013         |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0009864669 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0808       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000825    |
# |    value_loss           | 0.415        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.41e+04      |
# |    ep_rew_mean          | 529           |
# | time/                   |               |
# |    fps                  | 30            |
# |    iterations           | 16            |
# |    time_elapsed         | 1081          |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00014629378 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.89         |
# |    explained_variance   | 0.267         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 5.2           |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000427     |
# |    value_loss           | 19.7          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.41e+04     |
# |    ep_rew_mean          | 529          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 17           |
# |    time_elapsed         | 1156         |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0006110333 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.493        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 28.2         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 6.94e-05     |
# |    value_loss           | 68.1         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.41e+04      |
# |    ep_rew_mean          | 529           |
# | time/                   |               |
# |    fps                  | 29            |
# |    iterations           | 18            |
# |    time_elapsed         | 1229          |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00012228999 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.87         |
# |    explained_variance   | 0.289         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 15.7          |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000433     |
# |    value_loss           | 27.8          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+04    |
# |    ep_rew_mean          | 529         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 19          |
# |    time_elapsed         | 1301        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.001037033 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.16        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000776   |
# |    value_loss           | 0.493       |
# -----------------------------------------
# self.n_calls:  40000
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+04     |
# |    ep_rew_mean          | 640          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 20           |
# |    time_elapsed         | 1372         |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0008538659 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.332        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0628       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000812    |
# |    value_loss           | 0.249        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+04     |
# |    ep_rew_mean          | 640          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 21           |
# |    time_elapsed         | 1440         |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0021801374 |
# |    clip_fraction        | 0.000537     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.613        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 37.7         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00056     |
# |    value_loss           | 126          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.01e+04   |
# |    ep_rew_mean          | 640        |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 22         |
# |    time_elapsed         | 1508       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00517981 |
# |    clip_fraction        | 0.000537   |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.85      |
# |    explained_variance   | 0.804      |
# |    learning_rate        | 1e-06      |
# |    loss                 | 0.125      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00368   |
# |    value_loss           | 0.599      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+04     |
# |    ep_rew_mean          | 640          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 23           |
# |    time_elapsed         | 1574         |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0016504577 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.86        |
# |    explained_variance   | 0.00512      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0866       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 0.466        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 628          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 24           |
# |    time_elapsed         | 1640         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0006598136 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.87        |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0914       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000471    |
# |    value_loss           | 0.406        |
# ------------------------------------------
# self.n_calls:  50000
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 628          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 25           |
# |    time_elapsed         | 1706         |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0003004733 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.86        |
# |    explained_variance   | 0.474        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 52.4         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.000795     |
# |    value_loss           | 90.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 628         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 26          |
# |    time_elapsed         | 1775        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.001050325 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 29.6        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.000321    |
# |    value_loss           | 94.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 628         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 27          |
# |    time_elapsed         | 1842        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.001431836 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | -0.077      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0726      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00141    |
# |    value_loss           | 0.331       |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 628           |
# | time/                   |               |
# |    fps                  | 29            |
# |    iterations           | 28            |
# |    time_elapsed         | 1912          |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00014965821 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.83         |
# |    explained_variance   | 0.447         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 6.43          |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000408     |
# |    value_loss           | 20.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.46e+04     |
# |    ep_rew_mean          | 838          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 29           |
# |    time_elapsed         | 1983         |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0006151295 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.0997       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0774       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000307    |
# |    value_loss           | 0.388        |
# ------------------------------------------
# self.n_calls:  60000
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.46e+04     |
# |    ep_rew_mean          | 838          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 30           |
# |    time_elapsed         | 2056         |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0018689507 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.81        |
# |    explained_variance   | 0.6          |
# |    learning_rate        | 1e-06        |
# |    loss                 | 85.9         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.00131      |
# |    value_loss           | 236          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.46e+04     |
# |    ep_rew_mean          | 838          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 31           |
# |    time_elapsed         | 2125         |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0003131439 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.8         |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 8.41         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000537    |
# |    value_loss           | 19.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.46e+04    |
# |    ep_rew_mean          | 838         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 32          |
# |    time_elapsed         | 2193        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008875793 |
# |    clip_fraction        | 0.00859     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.104       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00565    |
# |    value_loss           | 0.366       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.34e+04     |
# |    ep_rew_mean          | 818          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 33           |
# |    time_elapsed         | 2258         |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0016098649 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.82        |
# |    explained_variance   | 0.0243       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0603       |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000627    |
# |    value_loss           | 0.271        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.34e+04     |
# |    ep_rew_mean          | 818          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 34           |
# |    time_elapsed         | 2321         |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0009484259 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 34.2         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.000102     |
# |    value_loss           | 90.5         |
# ------------------------------------------
# self.n_calls:  70000
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.19e+04      |
# |    ep_rew_mean          | 895           |
# | time/                   |               |
# |    fps                  | 29            |
# |    iterations           | 35            |
# |    time_elapsed         | 2393          |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00075295626 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.76         |
# |    explained_variance   | 0.705         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 27.9          |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 0.000106      |
# |    value_loss           | 82.2          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.19e+04     |
# |    ep_rew_mean          | 895          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 36           |
# |    time_elapsed         | 2464         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 7.378822e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.711        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 25.4         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -9.83e-05    |
# |    value_loss           | 50.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.19e+04     |
# |    ep_rew_mean          | 895          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 37           |
# |    time_elapsed         | 2535         |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0014598833 |
# |    clip_fraction        | 0.000684     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | 0.77         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 36.3         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 111          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.19e+04     |
# |    ep_rew_mean          | 895          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 38           |
# |    time_elapsed         | 2605         |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0068143075 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | -0.214       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.122        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 0.975        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.19e+04     |
# |    ep_rew_mean          | 895          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 39           |
# |    time_elapsed         | 2674         |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0012124925 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | -0.19        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0697       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000563    |
# |    value_loss           | 0.61         |
# ------------------------------------------
# self.n_calls:  80000
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+04    |
# |    ep_rew_mean          | 895         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 40          |
# |    time_elapsed         | 2746        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008447071 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | -0.155      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0671      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00424    |
# |    value_loss           | 0.49        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.19e+04      |
# |    ep_rew_mean          | 895           |
# | time/                   |               |
# |    fps                  | 29            |
# |    iterations           | 41            |
# |    time_elapsed         | 2819          |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00064756646 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.67         |
# |    explained_variance   | 0.803         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 57.5          |
# |    n_updates            | 400           |
# |    policy_gradient_loss | 0.000109      |
# |    value_loss           | 128           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+04    |
# |    ep_rew_mean          | 895         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 42          |
# |    time_elapsed         | 2893        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006638921 |
# |    clip_fraction        | 0.0233      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.137       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 0.394       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+04    |
# |    ep_rew_mean          | 895         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 43          |
# |    time_elapsed         | 2963        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.002793225 |
# |    clip_fraction        | 0.00107     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.121       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 0.29        |
# -----------------------------------------
# self.n_calls:  90000
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+04     |
# |    ep_rew_mean          | 926          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 44           |
# |    time_elapsed         | 3035         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0017582644 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | 0.404        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0459       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000489    |
# |    value_loss           | 0.177        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.27e+04      |
# |    ep_rew_mean          | 926           |
# | time/                   |               |
# |    fps                  | 29            |
# |    iterations           | 45            |
# |    time_elapsed         | 3100          |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00018720597 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.72         |
# |    explained_variance   | 0.875         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 29            |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.00021      |
# |    value_loss           | 78.5          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.27e+04      |
# |    ep_rew_mean          | 926           |
# | time/                   |               |
# |    fps                  | 29            |
# |    iterations           | 46            |
# |    time_elapsed         | 3174          |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00047118287 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.71         |
# |    explained_variance   | 0.705         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.77          |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000751     |
# |    value_loss           | 35.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+04     |
# |    ep_rew_mean          | 926          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 47           |
# |    time_elapsed         | 3243         |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0017448058 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | 0.224        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.11         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000401    |
# |    value_loss           | 0.374        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.27e+04   |
# |    ep_rew_mean          | 926        |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 48         |
# |    time_elapsed         | 3317       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00081039 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.69      |
# |    explained_variance   | 0.195      |
# |    learning_rate        | 1e-06      |
# |    loss                 | 0.0679     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -2.87e-05  |
# |    value_loss           | 0.308      |
# ----------------------------------------
# self.n_calls:  100000
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.27e+04      |
# |    ep_rew_mean          | 926           |
# | time/                   |               |
# |    fps                  | 29            |
# |    iterations           | 49            |
# |    time_elapsed         | 3391          |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00081669394 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.66         |
# |    explained_variance   | 0.857         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 66            |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000689     |
# |    value_loss           | 81.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+04     |
# |    ep_rew_mean          | 926          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 50           |
# |    time_elapsed         | 3457         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0052687908 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.63        |
# |    explained_variance   | -0.0053      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.151        |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 0.458        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+04     |
# |    ep_rew_mean          | 926          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 51           |
# |    time_elapsed         | 3530         |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0006868943 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | 0.673        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 31.4         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 36           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.27e+04    |
# |    ep_rew_mean          | 926         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 52          |
# |    time_elapsed         | 3603        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.003078515 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.07        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 0.248       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+04     |
# |    ep_rew_mean          | 926          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 53           |
# |    time_elapsed         | 3679         |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0005359608 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 38.5         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000309    |
# |    value_loss           | 129          |
# ------------------------------------------
# self.n_calls:  110000
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.27e+04    |
# |    ep_rew_mean          | 926         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 54          |
# |    time_elapsed         | 3751        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.005733175 |
# |    clip_fraction        | 0.00264     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0748      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00101    |
# |    value_loss           | 0.222       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.27e+04     |
# |    ep_rew_mean          | 926          |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 55           |
# |    time_elapsed         | 3825         |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0017365393 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.63        |
# |    explained_variance   | 0.239        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0718       |
# ...
# |    learning_rate        | 1e-06        |
# |    loss                 | 201          |
# |    n_updates            | 8160         |
# |    policy_gradient_loss | -5.79e-05    |
# |    value_loss           | 495          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.15e+03    |
# |    ep_rew_mean          | 2.02e+03    |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 818         |
# |    time_elapsed         | 62100       |
# |    total_timesteps      | 1675264     |
# | train/                  |             |
# |    approx_kl            | 0.002323382 |
# |    clip_fraction        | 0.000439    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 263         |
# |    n_updates            | 8170        |
# |    policy_gradient_loss | -0.000738   |
# |    value_loss           | 428         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.15e+03     |
# |    ep_rew_mean          | 2.02e+03     |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 819          |
# |    time_elapsed         | 62175        |
# |    total_timesteps      | 1677312      |
# | train/                  |              |
# |    approx_kl            | 0.0013249263 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.489       |
# |    explained_variance   | 0.779        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 299          |
# |    n_updates            | 8180         |
# |    policy_gradient_loss | 0.000275     |
# |    value_loss           | 512          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.15e+03     |
# |    ep_rew_mean          | 2e+03        |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 820          |
# |    time_elapsed         | 62246        |
# |    total_timesteps      | 1679360      |
# | train/                  |              |
# |    approx_kl            | 0.0010709252 |
# |    clip_fraction        | 0.00122      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 149          |
# |    n_updates            | 8190         |
# |    policy_gradient_loss | -0.00014     |
# |    value_loss           | 334          |
# ------------------------------------------
# self.n_calls:  1680000
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.16e+03     |
# |    ep_rew_mean          | 2.01e+03     |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 821          |
# |    time_elapsed         | 62322        |
# |    total_timesteps      | 1681408      |
# | train/                  |              |
# |    approx_kl            | 0.0003008252 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.503       |
# |    explained_variance   | 0.812        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 225          |
# |    n_updates            | 8200         |
# |    policy_gradient_loss | 0.000146     |
# |    value_loss           | 389          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.15e+03      |
# |    ep_rew_mean          | 2.01e+03      |
# | time/                   |               |
# |    fps                  | 26            |
# |    iterations           | 822           |
# |    time_elapsed         | 62393         |
# |    total_timesteps      | 1683456       |
# | train/                  |               |
# |    approx_kl            | 0.00011459194 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.453        |
# |    explained_variance   | 0.809         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 271           |
# |    n_updates            | 8210          |
# |    policy_gradient_loss | -5.3e-05      |
# |    value_loss           | 416           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | 2.01e+03    |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 823         |
# |    time_elapsed         | 62469       |
# |    total_timesteps      | 1685504     |
# | train/                  |             |
# |    approx_kl            | 0.003721642 |
# |    clip_fraction        | 0.00537     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.454      |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 1e-06       |
# |    loss                 | 75.2        |
# |    n_updates            | 8220        |
# |    policy_gradient_loss | -2.8e-05    |
# |    value_loss           | 353         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.18e+03  |
# |    ep_rew_mean          | 2.02e+03  |
# | time/                   |           |
# |    fps                  | 26        |
# |    iterations           | 824       |
# |    time_elapsed         | 62545     |
# |    total_timesteps      | 1687552   |
# | train/                  |           |
# |    approx_kl            | 0.0028617 |
# |    clip_fraction        | 0.00693   |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.383    |
# |    explained_variance   | 0.807     |
# |    learning_rate        | 1e-06     |
# |    loss                 | 176       |
# |    n_updates            | 8230      |
# |    policy_gradient_loss | -0.00112  |
# |    value_loss           | 487       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.17e+03     |
# |    ep_rew_mean          | 2e+03        |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 825          |
# |    time_elapsed         | 62620        |
# |    total_timesteps      | 1689600      |
# | train/                  |              |
# |    approx_kl            | 0.0012903364 |
# |    clip_fraction        | 0.00732      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.357       |
# |    explained_variance   | 0.843        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 198          |
# |    n_updates            | 8240         |
# |    policy_gradient_loss | -0.000663    |
# |    value_loss           | 346          |
# ------------------------------------------
# self.n_calls:  1690000
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.17e+03   |
# |    ep_rew_mean          | 1.99e+03   |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 826        |
# |    time_elapsed         | 62697      |
# |    total_timesteps      | 1691648    |
# | train/                  |            |
# |    approx_kl            | 0.00110295 |
# |    clip_fraction        | 0.00435    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.458     |
# |    explained_variance   | 0.8        |
# |    learning_rate        | 1e-06      |
# |    loss                 | 176        |
# |    n_updates            | 8250       |
# |    policy_gradient_loss | -0.000361  |
# |    value_loss           | 518        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.16e+03     |
# |    ep_rew_mean          | 1.98e+03     |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 827          |
# |    time_elapsed         | 62771        |
# |    total_timesteps      | 1693696      |
# | train/                  |              |
# |    approx_kl            | 0.0038528251 |
# |    clip_fraction        | 0.00166      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.485       |
# |    explained_variance   | 0.817        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 398          |
# |    n_updates            | 8260         |
# |    policy_gradient_loss | -0.000135    |
# |    value_loss           | 422          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.16e+03     |
# |    ep_rew_mean          | 1.98e+03     |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 828          |
# |    time_elapsed         | 62845        |
# |    total_timesteps      | 1695744      |
# | train/                  |              |
# |    approx_kl            | 0.0029656114 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.383       |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 317          |
# |    n_updates            | 8270         |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 505          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.15e+03     |
# |    ep_rew_mean          | 1.97e+03     |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 829          |
# |    time_elapsed         | 62921        |
# |    total_timesteps      | 1697792      |
# | train/                  |              |
# |    approx_kl            | 0.0011102556 |
# |    clip_fraction        | 0.0062       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.388       |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 202          |
# |    n_updates            | 8280         |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 580          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.15e+03     |
# |    ep_rew_mean          | 1.98e+03     |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 830          |
# |    time_elapsed         | 62996        |
# |    total_timesteps      | 1699840      |
# | train/                  |              |
# |    approx_kl            | 0.0008941168 |
# |    clip_fraction        | 0.00127      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.41        |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 201          |
# |    n_updates            | 8290         |
# |    policy_gradient_loss | -0.000323    |
# |    value_loss           | 587          |
# ------------------------------------------
# self.n_calls:  1700000
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.16e+03     |
# |    ep_rew_mean          | 1.98e+03     |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 831          |
# |    time_elapsed         | 63073        |
# |    total_timesteps      | 1701888      |
# | train/                  |              |
# |    approx_kl            | 0.0015571323 |
# |    clip_fraction        | 0.00708      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.452       |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 293          |
# |    n_updates            | 8300         |
# |    policy_gradient_loss | -0.000826    |
# |    value_loss           | 292          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.16e+03     |
# |    ep_rew_mean          | 2e+03        |
# | time/                   |              |
# |    fps                  | 26           |
# |    iterations           | 832          |
# |    time_elapsed         | 63148        |
# |    total_timesteps      | 1703936      |
# | train/                  |              |
# |    approx_kl            | 0.0025705318 |
# |    clip_fraction        | 0.00293      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.419       |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 113          |
# |    n_updates            | 8310         |
# |    policy_gradient_loss | -0.000743    |
# |    value_loss           | 391          |
# ------------------------------------------
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# D:\temp\ipykernel_26936\2755008103.py in <module>
#       4 callback1 = SaveOnBestTrainingRewardCallback(10000, save_model_dir)
#       5
# ----> 6 model.learn(total_timesteps=3000000,callback=callback1)
#       7 # model.save("mario_model")
#
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     317             tb_log_name=tb_log_name,
#     318             eval_log_path=eval_log_path,
# --> 319             reset_num_timesteps=reset_num_timesteps,
#     320         )
#
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     245         while self.num_timesteps < total_timesteps:
#     246
# --> 247             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     248
#     249             if continue_training is False:
#
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     149
#     150         n_steps = 0
# --> 151         rollout_buffer.reset()
#     152         # Sample new weights for the state dependent exploration
#     153         if self.use_sde:
#
# D:\Programs\anaconda\envs\cudapy7\lib\site-packages\stable_baselines3\common\buffers.py in reset(self)
#     358     def reset(self) -> None:
#     359
# --> 360         self.observations = np.zeros((self.buffer_size, self.n_envs) + self.obs_shape, dtype=np.float32)
#     361         self.actions = np.zeros((self.buffer_size, self.n_envs, self.action_dim), dtype=np.float32)
#     362         self.rewards = np.zeros((self.buffer_size, self.n_envs), dtype=np.float32)
#
# MemoryError: Unable to allocate 1.88 GiB for an array with shape (2048, 1, 4, 240, 256) and data type float32
